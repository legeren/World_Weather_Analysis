# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
citieswd = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    citywd = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if citywd not in citieswd:
        citieswd.append(citywd)
# Print the city count to confirm sufficient count.
len(citieswd)
# Out:
# 733

# %%
# Import the time library 
import time

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
citywd_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, citywd in enumerate(citieswd):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + citywd.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {citywd}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #Append the city information into city_data list.
        citywd_data.append({"City": citywd.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
                
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 4 | cape town
# Processing Record 2 of Set 4 | ushuaia
# Processing Record 3 of Set 4 | kieta
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | mataura
# Processing Record 6 of Set 4 | busselton
# Processing Record 7 of Set 4 | atuona
# Processing Record 8 of Set 4 | lorengau
# Processing Record 9 of Set 4 | iqaluit
# Processing Record 10 of Set 4 | saint-georges
# Processing Record 11 of Set 4 | chinsali
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | albany
# Processing Record 14 of Set 4 | itarema
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | poronaysk
# Processing Record 17 of Set 4 | altay
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | yellowknife
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | porosozero
# Processing Record 23 of Set 4 | faanui
# ...

# %%
len(citywd_data)
# Out:
# 754

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
citywd_data_df = pd.DataFrame(citywd_data)
citywd_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Cloudiness  Wind Speed  \
# 0      Cape Town      ZA -33.9258   18.4232     61.11          75        4.61
# 1        Ushuaia      AR -54.8000  -68.3000     36.12          83        6.80
# 2          Kieta      PG  -6.2167  155.6333     85.05          96        4.36
# 3   Constitucion      CL -35.3333  -72.4167     54.64          25       12.62
# 4        Mataura      NZ -46.1927  168.8643     56.26          75        3.49
# 5      Busselton      AU -33.6500  115.3333     58.41           0        9.33
# 6         Atuona      PF  -9.8000 -139.0333     79.34          32       16.02
# 7       Lorengau      PG  -2.0226  147.2712     84.42          18        5.39
# 8        Iqaluit      CA  63.7506  -68.5145      4.98          12        7.18
# 9  Saint-Georges      GD  12.0564  -61.7485     80.28          20       20.71
#
#         Description
# 0               fog
# 1     broken clouds
# 2   overcast clouds
# 3  scattered clouds
# ...

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
citywd_data_df.to_csv(output_data_file, index_label="City_ID")
